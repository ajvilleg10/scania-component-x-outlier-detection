# %% [markdown]
# # Exploración de artefactos EDA
#
# El EDA se genera automáticamente durante `--prepare-only`. Este notebook solo facilita la inspección; no forma parte del pipeline obligatorio.

# %%
from pathlib import Path
RUN = Path("/content/drive/MyDrive/TFM_SCANIA/experiments/runs/debug_025")
print("Tablas EDA:")
for p in sorted((RUN/"tables"/"eda").glob("*")): print(p.name)
print("\nFiguras EDA:")
for p in sorted((RUN/"figures"/"eda").glob("*.png")): print(p.name)
