# %% [markdown]
# # Análisis exploratorio complementario
#
# Notebook opcional para visualizar salidas generadas por `main.py --stage eda`.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
from pathlib import Path
ROOT = Path('/content/drive/MyDrive/TFM_SCANIA')
outputs = ROOT / 'outputs'
print(outputs)
