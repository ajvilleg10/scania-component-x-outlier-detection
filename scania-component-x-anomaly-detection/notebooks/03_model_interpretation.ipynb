# %% [markdown]
# # Interpretación de scores de outliers
#
# Notebook opcional para explorar puntuaciones de atipicidad por ventana y vehículo.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
from pathlib import Path
pred_dir = Path('/content/drive/MyDrive/TFM_SCANIA/outputs/predictions')
print(pred_dir)
