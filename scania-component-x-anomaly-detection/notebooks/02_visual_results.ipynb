# %% [markdown]
# # Visualización de resultados
#
# Notebook opcional para revisar métricas, predicciones y figuras generadas por el pipeline.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
from pathlib import Path
metrics_dir = Path('/content/drive/MyDrive/TFM_SCANIA/outputs/metrics')
list(metrics_dir.glob('*.csv'))[:10]
